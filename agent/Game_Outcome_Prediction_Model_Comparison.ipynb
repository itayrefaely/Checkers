# %%
import pandas as pd

# Read CSV file, including the first row
data = pd.read_csv('board_evals.csv', header=None)

# Define the column names as a list
column_names = ['Score', 'Captured', 'Potential', 'Regular Pawns', 'Kings', 'Capturables', 'Semi Capturables', 'Uncapturables', 'At Middle', 'Far', 'Is Over', 'Outcome']
data.columns = column_names

# %%
from sklearn.preprocessing import StandardScaler

# Scale the first column values
scaler = StandardScaler()
data['Score'] = scaler.fit_transform(data[['Score']])
print(data.head(10))
# Out:
#       Score  Captured  Potential  Regular Pawns  Kings  Capturables  \
# 0 -1.606480         0          1              0      0            0
# 1 -1.547084         0          0              0      0            0
# 2 -1.665875         0          1              0      0            0
# 3 -1.844062         0         -1              0      0            0
# 4 -1.309502         0          2              0      0            0
# 5 -1.428293         0          7              0      0            0
# 6 -0.715548         1          8              1      0           -1
# 7 -1.190711         1          0              0      0            0
# 8 -1.250107         1         -2              0      0            0
# 9 -1.190711         1          4              0      0            0
#
#    Semi Capturables  Uncapturables  At Middle  Far  Is Over  Outcome
# 0                 1             -1          1    0        0       -1
# 1                 0              1          0    0        0        1
# 2                 0              0          0    0        0       -1
# 3                 1             -1          0    0        0        1
# 4                 0              1          1    0        0       -1
# 5                 2             -2          0    0        0        1
# 6                 1              0          0    1        0       -1
# 7                 3             -1          1    0        0        1
# 8                 1              2         -1    0        0       -1
# 9                 4             -3          1    0        0        1

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# Split the data into features (X) and the target (y)
X = data.drop(columns=['Outcome'])  # Features (all columns except 'Outcome')
y = data['Outcome']  # Target variable ('Outcome' column)

# Split the data into training (70%) and test (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
X_train, X_test, y_train, y_test = np.array(X_train), np.array(X_test), np.array(y_train), np.array(y_test)

# %%
import torch
import torch.nn as nn

input_size = X_train.shape[1]
hidden_size = 64

# Define a list of optimizer configurations to try
optimizer_configs = [
    {"optimizer": torch.optim.SGD, "lr": 0.01},
    {"optimizer": torch.optim.SGD, "lr": 0.001},
    {"optimizer": torch.optim.SGD, "lr": 0.01, "momentum": 0.9},
    {"optimizer": torch.optim.Adam, "lr": 0.01},
    {"optimizer": torch.optim.Adam, "lr": 0.001},
    {"optimizer": torch.optim.RMSprop, "lr": 0.01},
    {"optimizer": torch.optim.RMSprop, "lr": 0.0001}
]

best_nn_model = None
best_nn_loss = float('inf')
best_optimizer_config = None

for config in optimizer_configs:
    # Create the neural network model with two hidden layers
    nn_model = nn.Sequential(
        nn.Linear(input_size, hidden_size),
        nn.ReLU(),
        nn.Linear(hidden_size, 1)  # Single output neuron for continuous score
    )

    criterion = nn.MSELoss()

    # Initialize the optimizer with the current configuration
    optimizer = config["optimizer"](nn_model.parameters(), lr=config["lr"])

    if "momentum" in config:
        optimizer = torch.optim.SGD(nn_model.parameters(), lr=config["lr"], momentum=config["momentum"])

    num_epochs = 100
    for epoch in range(num_epochs):
        train_inputs = torch.tensor(X_train, dtype=torch.float32)
        train_labels = torch.tensor(y_train.reshape(-1, 1), dtype=torch.float32)  # Continuous score

        # Forward pass
        train_outputs = nn_model(train_inputs)
        loss = criterion(train_outputs, train_labels)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print training statistics (e.g., loss) as needed
        if (epoch + 1) % 10 == 0:
            print(f'Configuration: {config}, Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

    # Check if this model has the lowest loss
    if loss < best_nn_loss:
        best_nn_loss = loss
        best_nn_model = nn_model
        best_optimizer_config = config


# Print the best model's loss and keep it as "best_model"
print(f"Best Model Loss: {best_nn_loss}, Best Configuration: {best_optimizer_config}")
# Out:
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01}, Epoch [10/100], Loss: 0.4076
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01}, Epoch [20/100], Loss: 0.3945
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01}, Epoch [30/100], Loss: 0.3865
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01}, Epoch [40/100], Loss: 0.3813
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01}, Epoch [50/100], Loss: 0.3778
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01}, Epoch [60/100], Loss: 0.3753
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01}, Epoch [70/100], Loss: 0.3734
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01}, Epoch [80/100], Loss: 0.3720
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01}, Epoch [90/100], Loss: 0.3708
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01}, Epoch [100/100], Loss: 0.3698
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.001}, Epoch [10/100], Loss: 0.4594
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.001}, Epoch [20/100], Loss: 0.4370
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.001}, Epoch [30/100], Loss: 0.4240
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.001}, Epoch [40/100], Loss: 0.4149
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.001}, Epoch [50/100], Loss: 0.4085
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.001}, Epoch [60/100], Loss: 0.4038
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.001}, Epoch [70/100], Loss: 0.4003
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.001}, Epoch [80/100], Loss: 0.3977
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.001}, Epoch [90/100], Loss: 0.3957
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.001}, Epoch [100/100], Loss: 0.3941
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01, 'momentum': 0.9}, Epoch [10/100], Loss: 0.4439
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01, 'momentum': 0.9}, Epoch [20/100], Loss: 0.3930
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01, 'momentum': 0.9}, Epoch [30/100], Loss: 0.3771
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01, 'momentum': 0.9}, Epoch [40/100], Loss: 0.3681
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01, 'momentum': 0.9}, Epoch [50/100], Loss: 0.3672
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01, 'momentum': 0.9}, Epoch [60/100], Loss: 0.3660
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01, 'momentum': 0.9}, Epoch [70/100], Loss: 0.3649
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01, 'momentum': 0.9}, Epoch [80/100], Loss: 0.3641
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01, 'momentum': 0.9}, Epoch [90/100], Loss: 0.3634
# Configuration: {'optimizer': <class 'torch.optim.sgd.SGD'>, 'lr': 0.01, 'momentum': 0.9}, Epoch [100/100], Loss: 0.3627
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}, Epoch [10/100], Loss: 0.4222
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}, Epoch [20/100], Loss: 0.3751
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}, Epoch [30/100], Loss: 0.3611
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}, Epoch [40/100], Loss: 0.3569
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}, Epoch [50/100], Loss: 0.3555
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}, Epoch [60/100], Loss: 0.3543
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}, Epoch [70/100], Loss: 0.3532
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}, Epoch [80/100], Loss: 0.3526
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}, Epoch [90/100], Loss: 0.3519
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}, Epoch [100/100], Loss: 0.3514
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.001}, Epoch [10/100], Loss: 0.4193
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.001}, Epoch [20/100], Loss: 0.3913
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.001}, Epoch [30/100], Loss: 0.3805
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.001}, Epoch [40/100], Loss: 0.3752
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.001}, Epoch [50/100], Loss: 0.3718
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.001}, Epoch [60/100], Loss: 0.3691
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.001}, Epoch [70/100], Loss: 0.3668
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.001}, Epoch [80/100], Loss: 0.3647
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.001}, Epoch [90/100], Loss: 0.3629
# Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.001}, Epoch [100/100], Loss: 0.3614
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.01}, Epoch [10/100], Loss: 0.3729
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.01}, Epoch [20/100], Loss: 0.3636
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.01}, Epoch [30/100], Loss: 0.3610
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.01}, Epoch [40/100], Loss: 0.3607
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.01}, Epoch [50/100], Loss: 0.3589
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.01}, Epoch [60/100], Loss: 0.3593
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.01}, Epoch [70/100], Loss: 0.3583
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.01}, Epoch [80/100], Loss: 0.3579
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.01}, Epoch [90/100], Loss: 0.3579
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.01}, Epoch [100/100], Loss: 0.3577
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.0001}, Epoch [10/100], Loss: 0.4145
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.0001}, Epoch [20/100], Loss: 0.3997
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.0001}, Epoch [30/100], Loss: 0.3918
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.0001}, Epoch [40/100], Loss: 0.3866
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.0001}, Epoch [50/100], Loss: 0.3827
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.0001}, Epoch [60/100], Loss: 0.3797
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.0001}, Epoch [70/100], Loss: 0.3773
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.0001}, Epoch [80/100], Loss: 0.3752
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.0001}, Epoch [90/100], Loss: 0.3734
# Configuration: {'optimizer': <class 'torch.optim.rmsprop.RMSprop'>, 'lr': 0.0001}, Epoch [100/100], Loss: 0.3719
# Best Model Loss: 0.3513869345188141, Best Configuration: {'optimizer': <class 'torch.optim.adam.Adam'>, 'lr': 0.01}

# %%
# Evaluate the best NN model on the test set
with torch.no_grad():
    test_inputs = torch.tensor(X_test, dtype=torch.float32)
    test_labels = torch.tensor(y_test.reshape(-1, 1), dtype=torch.float32)
    test_outputs = best_nn_model(test_inputs)
    test_loss = criterion(test_outputs, test_labels)
print("Test Loss:", test_loss.item())
# Out:
# Test Loss: 0.3519842028617859

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import BayesianRidge
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# Initialize variables to track the best model and its MSE
best_sk_model = None
best_sk_mse = float('inf')
best_sk_model_name = None 

models = {
    "Linear Regression": LinearRegression(),
    "Ridge": Ridge(),
    "Lasso": Lasso(),
    "Elastic Net": ElasticNet(),
    "Bayesian Ridge": BayesianRidge(),
    "Gradient Boosting Regressor": GradientBoostingRegressor(),
    "Extreme Gradient Boosting Regressor": XGBRegressor(objective="reg:squarederror")
}

for model_name, model in models.items():
    model.fit(X_train, y_train);
    y_preds = model.predict(X_test)

    # Evaluate the model performance 
    model_mse = mean_squared_error(y_preds, y_test)
    print(f"{model_name} MSE:", model_mse)

    # Check if this model has the lowest MSE
    if model_mse < best_sk_mse:
        best_sk_mse = model_mse
        best_sk_model = model
        best_sk_model_name = model_name

# Print the best model's MSE and store it as "best_model"
print(f"Best Model: {model_name}, Best Model MSE: {best_sk_mse}")
# Out:
# Linear Regression MSE: 0.35977350947392006
# Ridge MSE: 0.3597726009496467
# Lasso MSE: 0.3735709224939708
# Elastic Net MSE: 0.3735709224939708
# Bayesian Ridge MSE: 0.35977255358364735
# Gradient Boosting Regressor MSE: 0.3494929828661364
# Extreme Gradient Boosting Regressor MSE: 0.34323044788528667
# Best Model: Extreme Gradient Boosting Regressor, Best Model MSE: 0.34323044788528667

# %%
import pickle

# Save the best_sk_model to a file
model_filename = "agent_model.pkl"
with open(model_filename, 'wb') as file:
    pickle.dump(best_sk_model, file)
